# %%
import pandas as pd
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
import numpy as np
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
title_mapping ={"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }

train["Title"]=train["Name"].str.extract('([A-Za-z]+)\.',expand=False).map(title_mapping)
test['Title'] = test['Name'].str.extract('([A-Za-z]+)\.',expand=False).map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
#fill NAN entries in Age column with median of particular group (like Mr.,Mrss,Miss,etc) 

train['Age'].fillna(train.groupby('Title')['Age'].transform('median'), inplace=True)
test['Age'].fillna(test.groupby('Title')['Age'].transform('median'),inplace=True)

# %%
train.loc[ train['Age'] <= 16, 'Age'] = 0,
train.loc[(train['Age'] > 16) & (train['Age'] <= 26), 'Age'] = 1,
train.loc[(train['Age'] > 26) & (train['Age'] <= 36), 'Age'] = 2,
train.loc[(train['Age'] > 36) & (train['Age'] <= 62), 'Age'] = 3,
train.loc[ train['Age'] > 62, 'Age'] = 4
test.loc[ test['Age'] <= 16, 'Age'] = 0,
test.loc[(test['Age'] > 16) & (test['Age'] <= 26), 'Age'] = 1,
test.loc[(test['Age'] > 26) & (test['Age'] <= 36), 'Age'] = 2,
test.loc[(test['Age'] > 36) & (test['Age'] <= 62), 'Age'] = 3,
test.loc[ test['Age'] > 62, 'Age'] = 4

# %%
train.loc[ train['Fare'] <= 17, 'Fare'] = 0,
train.loc[(train['Fare'] > 17) & (train['Fare'] <= 30), 'Fare'] = 1,
train.loc[(train['Fare'] > 30) & (train['Fare'] <= 100), 'Fare'] = 2,
train.loc[ train['Fare'] > 100, 'Fare'] = 3
test.loc[ test['Fare'] <= 17, 'Fare'] = 0,
test.loc[(test['Fare'] > 17) & (test['Fare'] <= 30), 'Fare'] = 1,
test.loc[(test['Fare'] > 30) & (test['Fare'] <= 100), 'Fare'] = 2,
test.loc[ test['Fare'] > 100, 'Fare'] = 3

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
# train['Cabin']=train["Cabin"].str[:1]
# test['Cabin']=test["Cabin"].str[:1]

# cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
# train['Cabin'] = train['Cabin'].map(cabin_mapping)
# test['Cabin']=test["Cabin"].map(cabin_mapping)

# train['Cabin'].fillna(train.groupby('Pclass')['Cabin'].transform('median'),inplace=True)
# test['Cabin'].fillna(test.groupby('Pclass')['Cabin'].transform('median'),inplace=True)
# train = train.drop('Cabin',axis=1)
# test = test.drop('Cabin',axis=1)

train = train.drop('Cabin',axis=1)
test = test.drop('Cabin',axis=1)

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# Title          0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# Title          0
# dtype: int64

# %%
test['Fare'].fillna(test['Fare'].median(),inplace=True)

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Title          0
# dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'].fillna('S',inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Title          0
# dtype: int64

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  1.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  3.0      1
# 2                             Heikkinen, Miss. Laina  female  1.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  2.0      1
# 4                           Allen, Mr. William Henry    male  2.0      0
#
#    Parch            Ticket  Fare Embarked  Title
# 0      0         A/5 21171   0.0        S      0
# 1      0          PC 17599   2.0        C      2
# 2      0  STON/O2. 3101282   0.0        S      1
# 3      0            113803   2.0        S      2
# 4      0            373450   0.0        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#    Age  SibSp  Parch   Ticket  Fare Embarked  Title
# 0  2.0      0      0   330911   0.0        Q      0
# 1  3.0      1      0   363272   0.0        S      2
# 2  3.0      0      0   240276   0.0        Q      0
# 3  2.0      0      0   315154   0.0        S      0
# 4  1.0      1      1  3101298   0.0        S      2

# %%
train = train.drop('Name',axis=1)
test = test.drop('Name',axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    male  1.0      1      0         A/5 21171
# 1            2         1       1  female  3.0      1      0          PC 17599
# 2            3         1       3  female  1.0      0      0  STON/O2. 3101282
# 3            4         1       1  female  2.0      1      0            113803
# 4            5         0       3    male  2.0      0      0            373450
#
#    Fare Embarked  Title
# 0   0.0        S      0
# 1   2.0        C      2
# 2   0.0        S      1
# 3   2.0        S      2
# 4   0.0        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex  Age  SibSp  Parch   Ticket  Fare Embarked  \
# 0          892       3    male  2.0      0      0   330911   0.0        Q
# 1          893       3  female  3.0      1      0   363272   0.0        S
# 2          894       2    male  3.0      0      0   240276   0.0        Q
# 3          895       3    male  2.0      0      0   315154   0.0        S
# 4          896       3  female  1.0      1      1  3101298   0.0        S
#
#    Title
# 0      0
# 1      2
# 2      0
# 3      0
# 4      2

# %%
# gender_map={"male":0,"female":1}
# test["Sex"]=test["Sex"].map(gender_map)
# train["Sex"]=train["Sex"].map(gender_map)
# train.head()
df_train1 = pd.get_dummies(train[['Sex']])
df_train1.head(10)
# Out:
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           1         0
# 3           1         0
# 4           0         1
# 5           0         1
# 6           0         1
# 7           0         1
# 8           1         0
# 9           1         0

# %%
train = pd.concat([train,df_train1],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    male  1.0      1      0         A/5 21171
# 1            2         1       1  female  3.0      1      0          PC 17599
# 2            3         1       3  female  1.0      0      0  STON/O2. 3101282
# 3            4         1       1  female  2.0      1      0            113803
# 4            5         0       3    male  2.0      0      0            373450
#
#    Fare Embarked  Title  Sex_female  Sex_male
# 0   0.0        S      0           0         1
# 1   2.0        C      2           1         0
# 2   0.0        S      1           1         0
# 3   2.0        S      2           1         0
# 4   0.0        S      0           0         1

# %%
df_test1 = pd.get_dummies(test[['Sex']])
df_test1.head()
# Out:
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           0         1
# 3           0         1
# 4           1         0

# %%
test = pd.concat([test,df_test1],axis=1)

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex  Age  SibSp  Parch   Ticket  Fare Embarked  \
# 0          892       3    male  2.0      0      0   330911   0.0        Q
# 1          893       3  female  3.0      1      0   363272   0.0        S
# 2          894       2    male  3.0      0      0   240276   0.0        Q
# 3          895       3    male  2.0      0      0   315154   0.0        S
# 4          896       3  female  1.0      1      1  3101298   0.0        S
#
#    Title  Sex_female  Sex_male
# 0      0           0         1
# 1      2           1         0
# 2      0           0         1
# 3      0           0         1
# 4      2           1         0

# %%
train = train.drop('Sex',axis=1)
test =test.drop('Sex',axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch            Ticket  Fare  \
# 0            1         0       3  1.0      1      0         A/5 21171   0.0
# 1            2         1       1  3.0      1      0          PC 17599   2.0
# 2            3         1       3  1.0      0      0  STON/O2. 3101282   0.0
# 3            4         1       1  2.0      1      0            113803   2.0
# 4            5         0       3  2.0      0      0            373450   0.0
#
#   Embarked  Title  Sex_female  Sex_male
# 0        S      0           0         1
# 1        C      2           1         0
# 2        S      1           1         0
# 3        S      2           1         0
# 4        S      0           0         1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Age  SibSp  Parch   Ticket  Fare Embarked  Title  \
# 0          892       3  2.0      0      0   330911   0.0        Q      0
# 1          893       3  3.0      1      0   363272   0.0        S      2
# 2          894       2  3.0      0      0   240276   0.0        Q      0
# 3          895       3  2.0      0      0   315154   0.0        S      0
# 4          896       3  1.0      1      1  3101298   0.0        S      2
#
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           0         1
# 3           0         1
# 4           1         0

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Title          0
# Sex_female     0
# Sex_male       0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Title          0
# Sex_female     0
# Sex_male       0
# dtype: int64

# %%
#train = train.drop('Title',axis=1)
#test = test.drop('Title',axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch            Ticket  Fare  \
# 0            1         0       3  1.0      1      0         A/5 21171   0.0
# 1            2         1       1  3.0      1      0          PC 17599   2.0
# 2            3         1       3  1.0      0      0  STON/O2. 3101282   0.0
# 3            4         1       1  2.0      1      0            113803   2.0
# 4            5         0       3  2.0      0      0            373450   0.0
#
#   Embarked  Title  Sex_female  Sex_male
# 0        S      0           0         1
# 1        C      2           1         0
# 2        S      1           1         0
# 3        S      2           1         0
# 4        S      0           0         1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Age  SibSp  Parch   Ticket  Fare Embarked  Title  \
# 0          892       3  2.0      0      0   330911   0.0        Q      0
# 1          893       3  3.0      1      0   363272   0.0        S      2
# 2          894       2  3.0      0      0   240276   0.0        Q      0
# 3          895       3  2.0      0      0   315154   0.0        S      0
# 4          896       3  1.0      1      1  3101298   0.0        S      2
#
#    Sex_female  Sex_male
# 0           0         1
# 1           1         0
# 2           0         1
# 3           0         1
# 4           1         0

# %%
df_train2 = pd.get_dummies(train[['Embarked']])

# %%
df_train2.head()
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
train = pd.concat([train,df_train2],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch            Ticket  Fare  \
# 0            1         0       3  1.0      1      0         A/5 21171   0.0
# 1            2         1       1  3.0      1      0          PC 17599   2.0
# 2            3         1       3  1.0      0      0  STON/O2. 3101282   0.0
# 3            4         1       1  2.0      1      0            113803   2.0
# 4            5         0       3  2.0      0      0            373450   0.0
#
#   Embarked  Title  Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0        S      0           0         1           0           0           1
# 1        C      2           1         0           1           0           0
# 2        S      1           1         0           0           0           1
# 3        S      2           1         0           0           0           1
# 4        S      0           0         1           0           0           1

# %%
df_test2 = pd.get_dummies(test[['Embarked']])

# %%
df_test2.head()
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           1           0
# 1           0           0           1
# 2           0           1           0
# 3           0           0           1
# 4           0           0           1

# %%
test = pd.concat([test,df_test2],axis=1)

# %%
test.head()
# Out:
#    PassengerId  Pclass  Age  SibSp  Parch   Ticket  Fare Embarked  Title  \
# 0          892       3  2.0      0      0   330911   0.0        Q      0
# 1          893       3  3.0      1      0   363272   0.0        S      2
# 2          894       2  3.0      0      0   240276   0.0        Q      0
# 3          895       3  2.0      0      0   315154   0.0        S      0
# 4          896       3  1.0      1      1  3101298   0.0        S      2
#
#    Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0           0         1           0           1           0
# 1           1         0           0           0           1
# 2           0         1           0           1           0
# 3           0         1           0           0           1
# 4           1         0           0           0           1

# %%
train = train.drop(train[['Embarked','Ticket','PassengerId','Title']],axis=1)
test = test.drop(test[['Embarked','Ticket','Title']],axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  \
# 0         0       3  1.0      1      0   0.0           0         1
# 1         1       1  3.0      1      0   2.0           1         0
# 2         1       3  1.0      0      0   0.0           1         0
# 3         1       1  2.0      1      0   2.0           1         0
# 4         0       3  2.0      0      0   0.0           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  \
# 0          892       3  2.0      0      0   0.0           0         1
# 1          893       3  3.0      1      0   0.0           1         0
# 2          894       2  3.0      0      0   0.0           0         1
# 3          895       3  2.0      0      0   0.0           0         1
# 4          896       3  1.0      1      1   0.0           1         0
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           1           0
# 1           0           0           1
# 2           0           1           0
# 3           0           0           1
# 4           0           0           1

# %%
#train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
#test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
#family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
#train['FamilySize'] = train['FamilySize'].map(family_mapping)
#test['FamilySize']=test['FamilySize'].map(family_mapping)

# %%
train.head()
# Out:
#    Survived  Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  \
# 0         0       3  1.0      1      0   0.0           0         1
# 1         1       1  3.0      1      0   2.0           1         0
# 2         1       3  1.0      0      0   0.0           1         0
# 3         1       1  2.0      1      0   2.0           1         0
# 4         0       3  2.0      0      0   0.0           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  \
# 0          892       3  2.0      0      0   0.0           0         1
# 1          893       3  3.0      1      0   0.0           1         0
# 2          894       2  3.0      0      0   0.0           0         1
# 3          895       3  2.0      0      0   0.0           0         1
# 4          896       3  1.0      1      1   0.0           1         0
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           1           0
# 1           0           0           1
# 2           0           1           0
# 3           0           0           1
# 4           0           0           1

# %%
# train['new'] = train['Fare']+train['Cabin']
# test['new'] = train['Fare']+train['Cabin']
# train = train.drop('Embarked_S',axis=1)
# test = test.drop('Embarked_S',axis=1)

# %%
y_train = train['Survived']
X_train = train.drop('Survived',axis=1)
X_test = test.drop('PassengerId',axis=1)

# %%
X_train.head()
# Out:
#    Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  1.0      1      0   0.0           0         1           0
# 1       1  3.0      1      0   2.0           1         0           1
# 2       3  1.0      0      0   0.0           1         0           0
# 3       1  2.0      1      0   2.0           1         0           0
# 4       3  2.0      0      0   0.0           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
X_train.isnull().sum()
# Out:
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
#below code is for calculating importances of each feature in training set
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators=10000,random_state=0,n_jobs=-1)

forest.fit(X_train,y_train)

labels=X_train.columns[:]

# %%
importances = forest.feature_importances_

indices = np.argsort(importances)[::-1]

for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30,labels[f],importances[indices[f]]))
# Out:
#  1) Pclass                         0.201163
#  2) Age                            0.198394
#  3) SibSp                          0.139626
#  4) Parch                          0.139211
#  5) Fare                           0.101802
#  6) Sex_female                     0.088923
#  7) Sex_male                       0.077212
#  8) Embarked_C                     0.021665
#  9) Embarked_Q                     0.020840
# 10) Embarked_S                     0.011165

# %%
import matplotlib.pyplot as plt
plt.title('Feature Importances')
plt.bar(range(X_train.shape[1]),importances[indices],color='blue',align='center')
plt.xticks(range(X_train.shape[1]),labels, rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

ppn = Perceptron(n_iter=50, eta0=0.1, random_state=0)
ppn.fit(X_train, y_train)

y_pred = ppn.predict(X_train)
print('no. of misclassification errors : %d' % (y_train != y_pred).sum())
print('Accuracy: ', accuracy_score(y_train, y_pred))
# Out:
# no. of misclassification errors : 177
# Accuracy:  0.8013468013468014
# C:\Users\wishw\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=9)
lr = LogisticRegression()
# X_train_pca = pca.fit_transform(X_train_std)
# X_test_pca = pca.transform(X_test_std)

# %%
lr.fit(X_train_std,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred=lr.predict(X_train_std)

# %%
print("Accuracy:",accuracy_score(y_train,y_pred))
# Out:
# Accuracy: 0.8047138047138047

# %%
from sklearn.svm import SVC

# %%
ppn=SVC()

# %%
ppn=SVC(kernel='rbf', random_state=1, gamma=100.0, C=10.0)

# %%
ppn.fit(X_train_std,y_train)
# Out:
# SVC(C=10.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=100.0, kernel='rbf',
#   max_iter=-1, probability=False, random_state=1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
prediction=ppn.predict(X_train_std)

# %%
print("Accuracy:",accuracy_score(y_train,prediction))
# Out:
# Accuracy: 0.8832772166105499

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
ppn=DecisionTreeClassifier(criterion='entropy',max_depth=5, random_state=0)

# %%
ppn.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
prediction=ppn.predict(X_train)

# %%
print("Accuracy:",accuracy_score(y_train,prediction))
print('no. of misclassification errors : %d' % (y_train != prediction).sum())
# Out:
# Accuracy: 0.8372615039281706
# no. of misclassification errors : 145

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ppn=RandomForestClassifier(criterion='entropy',n_estimators=200,random_state=1,n_jobs=2)

# %%
ppn.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=2,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
prediction=ppn.predict(X_train)

# %%
print("Accuracy:",accuracy_score(y_train,prediction))
# Out:
# Accuracy: 0.8832772166105499

# %%
X_train.head()
# Out:
#    Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  1.0      1      0   0.0           0         1           0
# 1       1  3.0      1      0   2.0           1         0           1
# 2       3  1.0      0      0   0.0           1         0           0
# 3       1  2.0      1      0   2.0           1         0           0
# 4       3  2.0      0      0   0.0           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
X_test.head()
# Out:
#    Pclass  Age  SibSp  Parch  Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  2.0      0      0   0.0           0         1           0
# 1       3  3.0      1      0   0.0           1         0           0
# 2       2  3.0      0      0   0.0           0         1           0
# 3       3  2.0      0      0   0.0           0         1           0
# 4       3  1.0      1      1   0.0           1         0           0
#
#    Embarked_Q  Embarked_S
# 0           1           0
# 1           0           1
# 2           1           0
# 3           0           1
# 4           0           1

# %%
prediction=ppn.predict(X_test)

# %%
submission = pd.DataFrame({"PassengerId": test["PassengerId"],"Survived": prediction})

submission.to_csv('submission4.csv', index=False)
